# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import theano.tensor as T
import pymc3 as pm
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az

# %%
dummy_data = np.loadtxt('../data/dummy.csv')

# %%
x_1 = dummy_data[:,0]
y_1 = dummy_data[:,1]

# %%
order = 2

# %%
x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
y_1s = (y_1 - y_1.mean()) / y_1.std()
plt.scatter(x_1s[0], y_1s)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
y_1s
x_1s
# Out:
# array([[-1.72414181, -1.5947931 , -1.41718994, -1.32135125, -1.33810627,
#         -1.23087417, -0.96480453, -0.95877273, -0.85556184, -0.73492573,
#         -0.56871598, -0.41591024, -0.4795793 , -0.44137787, -0.17932943,
#         -0.12839419,  0.04786857,  0.11890983,  0.31862961,  0.3072362 ,
#          0.36085225,  0.5310832 ,  0.69863335,  0.69662275,  0.85344969,
#          0.95263938,  1.12354053,  1.0907007 ,  1.26897406,  1.33800472,
#          1.37151475,  1.61412737,  1.66104141],
#        [-0.6811725 , -0.76003053, -0.84312138, -0.87585202, -0.87074204,
#         -0.89896365, -0.92310164, -0.9228906 , -0.91407052, -0.89128571,
#         -0.83786718, -0.76623575, -0.7987041 , -0.77967256, -0.61277348,
#         -0.57296772, -0.41671773, -0.34562583, -0.12078093, -0.13459894,
#         -0.06852717,  0.15885519,  0.40880321,  0.40565007,  0.66281204,
#          0.83719337,  1.15897266,  1.09504594,  1.45405472,  1.6009563 ,
#          1.67385522,  2.23259249,  2.34691077]])

# %%
# first linear
with pm.Model() as model_l: 
    
    # priors
    α = pm.Normal('α', mu = 0, sd = 5)
    β = pm.Normal('β', mu = 0, sd = 2) #2 predictors?
    ϵ = pm.HalfNormal('ϵ', 2)
    
    # linear model
    μ = pm.Deterministic('μ', α + β * x_1s[0]) 
    
    # likelihood
    y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)
    
    # sample 
    trace_l = pm.sample(2000, cores = 1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [ϵ, β, α]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:04<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:02<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 7 seconds.

# %%
# second order term: 
with pm.Model() as model_p: 
    
    # priors
    α = pm.Normal('α', mu = 0, sd = 5)
    β = pm.Normal('β', mu = 0, sd = 2, shape = order) #2 predictors?
    ϵ = pm.HalfNormal('ϵ', 2)
    
    # linear model
    #μ = pm.Deterministic('μ', α + β[0] * x_1s[0] + β[1] * x_1s[1]) 
    μ = α + pm.math.dot(β, x_1s) 
    
    # likelihood
    y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)
    
    # sample 
    trace_p = pm.sample(2000, cores = 1)
    
    # plot trace
    az.plot_trace(trace_p)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [ϵ, β, α]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:04<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:05<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 10 seconds.

# %%
## linear model
# plot some nice stuff
x_new = np.linspace(x_1s[0].min(), x_1s[0].max(), 100)

# mean alpha
α_l_post = trace_l['α'].mean()

# mean beta?
β_l_post = trace_l['β'].mean(axis = 0)

# model post for each
y_l_post = α_l_post + β_l_post * x_new

plt.plot(x_new, y_l_post, 'C1', label = 'linear model')

## quadratic
α_p_post = trace_p['α'].mean()
β_p_post = trace_p['β'].mean(axis = 0)
idx = np.argsort(x_1s[0])
y_p_post = α_p_post + np.dot(β_p_post, x_1s)

plt.plot(x_1s[0][idx], y_p_post[idx], 'C2', 
        label = f'model order {order}')

x_new_p = np.vstack([x_new**i for i in range(1, order + 1)])
y_p_post = α_p_post + np.dot(β_p_post, x_new_p)

plt.scatter(x_1s[0], y_1s, c = 'C0', marker = ".")
plt.legend()

# %%
# posterior predictions
y_l = pm.sample_posterior_predictive(trace_l, 2000, 
                                    model = model_l)['y']
y_p = pm.sample_posterior_predictive(trace_p, 2000,
                                    model = model_p)['y']
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\sampling.py:1690: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   warnings.warn(
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00]
#     </div>
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\sampling.py:1690: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   warnings.warn(
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00]
#     </div>

# %%
# IQR visualization
plt.figure(figsize = (8, 3))
data = [y_1s, y_l, y_p]
labels = ['data', 'linear model', 'order 2']
for i, d in enumerate(data): 
    mean = d.mean()
    err = np.percentile(d, [25, 75])
    plt.errorbar(mean, -i, xerr = [[-err[0]], [err[1]]], fmt = 'o')
    plt.text(mean, -i + 0.2, labels[i], ha = 'center', fontsize = 14)
plt.ylim([-i-0.5, 0.5])
plt.yticks([])
# Out:
# ([], [])

# %%
# dispersion
fig, ax = plt.subplots(1, 2, figsize = (10, 3), constrained_layout = True)

def iqr(x, a = 0):
    return np.subtract(*np.percentile(x, [75, 25], axis = a))

for idx, func in enumerate([np.mean, iqr]):
    T_obs = func(y_1s)
    ax[idx].axvline(T_obs, 0, 1, color = 'k', ls = '--')
    
    for d_sim, c in zip([y_l, y_p], ['C1', 'C2']):
        T_sim = func(d_sim, 1)
        p_value = np.mean(T_sim >= T_obs)
        az.plot_kde(T_sim, plot_kwargs = {'color': c},
                   label = f'p-value {p_value:.2f}',
                   ax = ax[idx])
        ax[idx].set_title(func.__name__)
        ax[idx].set_yticks([])
        ax[idx].legend()

# %%
# least squares (basically flat prior)
x = np.array([4, 5, 6, 9, 12, 14])
y = np.array([4.2, 6, 6, 9, 10, 10])

plt.figure(figsize = (10, 5))
order = [0, 1, 2, 5]
plt.plot(x, y, 'o')

for i in order:
    x_n = np.linspace(x.min(), x.max(), 100)
    coeffs = np.polyfit(x, y, deg = i)
    ffit = np.polyval(coeffs, x_n)
    p = np.poly1d(coeffs)
    yhat = p(x)
    ybar = np.mean(y)
    ssreg = np.sum((yhat - ybar)**2)
    sstot = np.sum((y - ybar)**2)
    r2 = ssreg / sstot
    
    plt.plot(x_n, ffit, label = f'order {i}, $R^2$ = {r2:.2f}')

plt.legend(loc = 2)
plt.xlabel('x')
plt.ylabel('y', rotation = 0)
# Out:
# Text(0, 0.5, 'y')

# %%
# this seems to have changed. 
waic_l = az.waic(trace_l)
waic_l
# Out:
# Computed from 4000 by 33 log-likelihood matrix
#
#           Estimate       SE
# elpd_waic   -14.33     2.70
# p_waic        2.45        -

# %%
cmp_df = az.compare({'model_l': trace_l,
                   'model_p': trace_p},
                    method = 'stacking')
cmp_df
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:146: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   warnings.warn(
#          rank        loo     p_loo     d_loo  weight        se       dse  \
# model_p     0  -4.595314  2.667957  0.000000     1.0  2.350947  0.000000
# model_l     1 -14.357017  2.471376  9.761704     0.0  2.703827  2.655738
#
#          warning loo_scale
# model_p    False       log
# model_l    False       log

# %%
az.plot_compare(cmp_df)
# Out:
# <AxesSubplot:xlabel='Log'>

# %%
cmp_df1 = az.compare({'model_l': trace_l,
                   'model_p': trace_p},
                    method = 'BB-pseudo-BMA')
cmp_df1
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:146: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   warnings.warn(
#          rank        loo     p_loo     d_loo    weight        se       dse  \
# model_p     0  -4.595314  2.667957  0.000000  0.998239  2.659576  0.000000
# model_l     1 -14.357017  2.471376  9.761704  0.001761  2.234199  2.655738
#
#          warning loo_scale
# model_p    False       log
# model_l    False       log

# %%
# weighted posterior predictive sample
w = 0.5 #weight them equally?
y_lp = pm.sample_posterior_predictive_w(
    [trace_l, trace_p],
    samples = 1000,
    models = [model_l, model_p],
    weights = [w, 1-w])

_, ax = plt.subplots(figsize = (10, 6))
az.plot_kde(y_l, plot_kwargs = {'color': 'C1'},
           label = 'linear model', ax = ax)
az.plot_kde(y_p, plot_kwargs = {'color': 'C2'},
           label = 'order 2 model', ax = ax)
az.plot_kde(y_lp['y'], plot_kwargs = {'color': 'C3'},
           label = 'weighted model', ax = ax)

plt.plot(y_1s, np.zeros_like(y_1s), '|', label = 'observed data')
plt.yticks([])
plt.legend()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:01<00:00]
#     </div>

# %% [markdown]
# ## Bayes Factor

# %%
coins = 30
heads = 9
y_d = np.repeat([0, 1], [coins-heads, heads])

# %%
# could this be done with tensor instead of math?
with pm.Model() as model_BF:
    p = np.array([0.5, 0.5])
    model_index = pm.Categorical('model_index', p = p)
    
    m_0 = (4, 8)
    m_1 = (8, 4)
    m = pm.math.switch(pm.math.eq(model_index, 0), m_0, m_1)
    
    # a priori
    θ = pm.Beta('θ', m[0], m[1])
    
    # likelihood
    y = pm.Bernoulli('y', θ, observed = y_d)
    
    trace_BF = pm.sample(5000, cores = 1)
# Out:
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >BinaryGibbsMetropolis: [model_index]
# >NUTS: [θ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:05<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6000' class='' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6000/6000 00:05<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 11 seconds.
# The acceptance probability does not match the target. It is 0.8986251403331913, but should be close to 0.8. Try to increase the number of tuning steps.

# %% [markdown]
# # Sequential Monte Carlo (SMC)

# %%
with pm.Model() as model_BF_0:
    θ = pm.Beta('θ', 4, 8)
    y = pm.Bernoulli('y', θ, observed = y_d)
    trace_BF_0 = pm.sample_smc(2500, cores = 1)
    
with pm.Model() as model_BF_1:
    θ = pm.Beta('θ', 8, 4)
    y = pm.Bernoulli('y', θ, observed = y_d)
    trace_BF_1 = pm.sample_smc(2500, cores = 1)
# Out:
# Initializing SMC sampler...
# Sampling 2 chains in 1 job
# Stage:   0 Beta: 1.000
# Stage:   0 Beta: 1.000
# Initializing SMC sampler...
# Sampling 2 chains in 1 job
# Stage:   0 Beta: 0.210
# Stage:   1 Beta: 0.689
# Stage:   2 Beta: 1.000
# Stage:   0 Beta: 0.209
# Stage:   1 Beta: 0.678
# Stage:   2 Beta: 1.000

# %%
# marginal likelihood appears to have changed also. 
# not sure why there are two numbers: but both are close to the 11 mentioned in the book. 
BF_smc = np.exp(trace_BF_0.report.log_marginal_likelihood - trace_BF_1.report.log_marginal_likelihood)
np.round(BF_smc)
# Out:
# array([11., 11.])

# %% [markdown]
# # Bayes factor & IC

# %%
traces = []
waics = []

for coins, heads in [(30, 9), (300, 90)]:
    y_d = np.repeat([0, 1], [coins-heads, heads])
    for priors in [(4, 8), (8, 4)]:
        with pm.Model() as model:
            θ = pm.Beta('θ', *priors)
            y = pm.Bernoulli('y', θ, observed = y_d)
            trace = pm.sample(2000, cores = 1)
            traces.append(trace)
            waics.append(az.waic(trace))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [θ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:02<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 4 seconds.
# The acceptance probability does not match the target. It is 0.8900213697353652, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [θ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 4 seconds.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [θ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 4 seconds.
# The acceptance probability does not match the target. It is 0.8809399504114508, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [θ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:01<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 4 seconds.

# %%
#hmm
fig, ax = plt.subplots(1, 2, sharey = True)

labels = ['model0', 'model1', 'model0']
indices = [0, 0, 1, 1]

for i, (ind, d) in enumerate(zip(indices, waics)):
    mean = d.waic
    ax[ind].errorbar(mean, -i, xerr = d.waic_se, fmt = 'o')
    ax[ind].text(mean, -i + 0.2, labels[i], ha = 'center')
    
ax[0].set_xlim(30, 50)
ax[1].set_xlim(330, 400)
plt.ylim([-i-0.5, 0.5])
plt.yticks([])
plt.subplots_adjust(wspace = 0.05)
fig.text(0.5, 0, 'Deviance', ha = 'center', fontsize = 14)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-42af308a26e4> in <module>
#       8     mean = d.waic
#       9     ax[ind].errorbar(mean, -i, xerr = d.waic_se, fmt = 'o')
# ---> 10     ax[ind].text(mean, -i + 0.2, labels[i], ha = 'center')
#      11
#      12 ax[0].set_xlim(30, 50)
#
# IndexError: list index out of range

# %% [markdown]
# # Regularizing priors

# %%
# ridge regression
# lasso regression

# %% [markdown]
# # Entropy

# %%
from scipy import stats

# %%
x = range(0, 10)
q = stats.binom(10, .75)
r = stats.randint(0, 10)

true_distribution = [list(q.rvs(200)).count(i) / 200 for i in x]

q_pmf = q.pmf(x)
r_pmf = r.pmf(x)

_, ax = plt.subplots(1, 3, figsize = (12, 4),
                    sharey = True, constrained_layout = True)

for idx, (dist, label) in enumerate(zip([true_distribution, q_pmf, r_pmf],
                                       ['true_distribution', 'q', 'r'])):
    ax[idx].vlines(x, 0, dist, label = f'entropy = {stats.entropy(dist):.2f}')
    ax[idx].set_title(label)
    ax[idx].set_yticks(x)
    ax[idx].legend(loc = 2, handlelength = 0)

# %%
stats.entropy(true_distribution, q_pmf), stats.entropy(true_distribution, r_pmf)

# %% [markdown]
# # Exercises

# %% [markdown]
# ## E1:
# This exercise is about regularization priors. In the code that generates the data,
# change order=2 to another value, such as order=5. Then, fit model_p and plot
# the resulting curve. Repeat this, but now using a prior for beta with sd=100
# instead of sd=1 and plot the resulting curve. How are both curves different? Try
# this out with sd=np.array([10, 0.1, 0.1, 0.1, 0.1]), too.

# %%
# from earlier
dummy_data = np.loadtxt('../data/dummy.csv')
x_1 = dummy_data[:,0]
y_1 = dummy_data[:,1]

# %%
# second order term: 
traces = []

for order in [2, 5]: 
    x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
    x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
    y_1s = (y_1 - y_1.mean()) / y_1.std()
    for beta_sd in [1, 100]: 
        with pm.Model() as E1model_p: 

            # priors
            α = pm.Normal('α', mu = 0, sd = 5)
            β = pm.Normal('β', mu = 0, sd = beta_sd, shape = order) 
            ϵ = pm.HalfNormal('ϵ', 2)

            # linear model
            #μ = pm.Deterministic('μ', α + β[0] * x_1s[0] + β[1] * x_1s[1]) 
            μ = α + pm.math.dot(β, x_1s) 

            # likelihood
            y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)

            # sample 
            trace = pm.sample(2000, cores = 1)
            
            # append
            traces.append(trace)

# %%
# first the two with order = 5

# %%
order = 5
x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
y_1s = (y_1 - y_1.mean()) / y_1.std()

# %%
# first some linspace
x_new = np.linspace(x_1s[0].min(), x_1s[0].max(), 100)
order = 5

# then a loop 
for trace in traces[2:]: # the last two. 
    α_post = trace['α'].mean()
    β_post = trace['β'].mean(axis = 0)
    idx = np.argsort(x_1s[0]) #has to be the right one.. 
    y_post = α_post + np.dot(β_post, x_1s)
    
    plt.plot(x_1s[0][idx], y_post[idx], 'C2', label = f'model {trace}')
    
    x_new_p = np.vstack([x_new**i for i in range(1, order + 1)]) #need to know order..
    y_p_post = α_p_post + np.dot(β_post, x_new_p)

    plt.scatter(x_1s[0], y_1s, c = 'C0', marker = ".")
    plt.legend()

# %%
# then with order = 2
order = 2
x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
y_1s = (y_1 - y_1.mean()) / y_1.std()

# %%
# first some linspace
x_new = np.linspace(x_1s[0].min(), x_1s[0].max(), 100)

# then a loop 
for trace in traces[:2]: # the last two. 
    α_post = trace['α'].mean()
    β_post = trace['β'].mean(axis = 0)
    idx = np.argsort(x_1s[0]) #has to be the right one.. 
    y_post = α_post + np.dot(β_post, x_1s)
    
    plt.plot(x_1s[0][idx], y_post[idx], 'C2', label = f'model {trace}')
    
    x_new_p = np.vstack([x_new**i for i in range(1, order + 1)]) #need to know order..
    y_p_post = α_p_post + np.dot(β_post, x_new_p)

    plt.scatter(x_1s[0], y_1s, c = 'C0', marker = ".")
    plt.legend()

# %%
# interrim: 
# SD does not really matter for the order = 2 polynomial.
# SD does matter for order = 5 polynomial.
# too high SD and it cannot properly fit.

# %%
# now trying with sd = np.array([10, 0.1, 0.1, 0.1, 0.1])
# guess we just tell it that we think that for the first beta it could vary more..
# second order term: 
order = 5
x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
y_1s = (y_1 - y_1.mean()) / y_1.std()
beta_sd = np.array([10, 0.1, 0.1, 0.1, 0.1])

with pm.Model() as E1model_p: 

    # priors
    α = pm.Normal('α', mu = 0, sd = 5)
    β = pm.Normal('β', mu = 0, sd = beta_sd, shape = order) 
    ϵ = pm.HalfNormal('ϵ', 2)

    # linear model
    #μ = pm.Deterministic('μ', α + β[0] * x_1s[0] + β[1] * x_1s[1]) 
    μ = α + pm.math.dot(β, x_1s) 

    # likelihood
    y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)

    # sample 
    trace = pm.sample(2000, cores = 1)

# %%
az.plot_trace(trace) #much better fit.

# %% [markdown]
# ## E2:
# Repeat the previous exercise but increase the amount of data to 500 data points.

# %%
# from earlier
dummy_data = np.loadtxt('../data/dummy.csv')
dummy_data = np.concatenate([dummy_data] * 15)
x_1 = dummy_data[:,0]
y_1 = dummy_data[:,1]

# %%
# running models again
# second order term: 
traces2 = []

for order in [2, 5]: 
    x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
    x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
    y_1s = (y_1 - y_1.mean()) / y_1.std()
    for beta_sd in [1, 100]: 
        with pm.Model() as E1model_p: 

            # priors
            α = pm.Normal('α', mu = 0, sd = 5)
            β = pm.Normal('β', mu = 0, sd = beta_sd, shape = order) 
            ϵ = pm.HalfNormal('ϵ', 2)

            # linear model
            #μ = pm.Deterministic('μ', α + β[0] * x_1s[0] + β[1] * x_1s[1]) 
            μ = α + pm.math.dot(β, x_1s) 

            # likelihood
            y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)

            # sample 
            trace = pm.sample(2000, cores = 1)
            
            # append
            traces2.append(trace)

# %%
# not sure the fit is actually that much better?

# %% [markdown]
# ## E3:
# Fit a cubic model (order 3), compute WAIC and LOO, plot the results, and
# compare them with the linear and quadratic models.

# %%
# load data again:
# from earlier
dummy_data = np.loadtxt('../data/dummy.csv')
x_1 = dummy_data[:,0]
y_1 = dummy_data[:,1]

# %%
# first, second, third order
traces3 = []
waics3 = []
for order in [1, 2, 3]:
    x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
    x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
    y_1s = (y_1 - y_1.mean()) / y_1.std()
    with pm.Model() as model: 

        # priors
        α = pm.Normal('α', mu = 0, sd = 5)
        β = pm.Normal('β', mu = 0, sd = 2, shape = order) #2 predictors?
        ϵ = pm.HalfNormal('ϵ', 2)

        # linear model
        #μ = pm.Deterministic('μ', α + β[0] * x_1s[0] + β[1] * x_1s[1]) 
        μ = α + pm.math.dot(β, x_1s) 

        # likelihood
        y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)

        # sample 
        trace = pm.sample(2000, cores = 1)
        
        # append stuff
        waics3.append(az.waic(trace))
        traces3.append(trace)

# %%
# WAIC comparison. 
# order 2 is best. 
cmp_df = az.compare({'linear': traces3[0],
                     'order 2': traces[1],
                     'order 3': traces3[2]},
                    method = 'stacking')
cmp_df

# %%
test = [1, 2, 3]
for i, num in enumerate(test[1:]):
    print(i)
    print(num)

# %%
# load data again:
# from earlier
dummy_data = np.loadtxt('../data/dummy.csv')
x_1 = dummy_data[:,0]
y_1 = dummy_data[:,1]

# %%
# plot them.
# first some linspace
x_new = np.linspace(x_1s[0].min(), x_1s[0].max(), 100)

# for the linear
# mean alpha
α_l_post = traces3[0]['α'].mean()

# mean beta?
β_l_post = traces3[0]['β'].mean(axis = 0)

# model post for each
y_l_post = α_l_post + β_l_post * x_new

plt.plot(x_new, y_l_post, 'C1', label = 'linear model')

# then a loop 
for order, trace in enumerate(traces3[1:]): # deselect the first one
    
    # preprocessing
    x_1p = np.vstack([x_1**i for i in range(1, order + 3)])
    x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
    y_1s = (y_1 - y_1.mean()) / y_1.std()

    α_post = trace['α'].mean()
    β_post = trace['β'].mean(axis = 0)
    
    idx = np.argsort(x_1s[0]) #has to be the right one.. 
    y_post = α_post + np.dot(β_post, x_1s)
    
    plt.plot(x_1s[0][idx], y_post[idx], 'C2', label = f'model {trace}')
    
    x_new_p = np.vstack([x_new**i for i in range(1, order + 3)]) #need to know order..
    y_p_post = α_p_post + np.dot(β_post, x_new_p)

    plt.scatter(x_1s[0], y_1s, c = 'C0', marker = ".")
    plt.legend()

# %%
# makes sense that the second order would be better than third order
# since their fit is almost exactly the same.

# %% [markdown]
# ## E4:
# Use pm.sample_posterior_predictive() to rerun the PPC example, but this
# time, plot the values of y instead of the values of the mean. <br/>
# NB: What PPC example does he mean?

# %%
# load data again:
# from earlier
dummy_data = np.loadtxt('../data/dummy.csv')
x_1 = dummy_data[:,0]
y_1 = dummy_data[:,1]

# %%
# running model "l" and model "p"
# preprocessing
order = 1
x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
y_1s = (y_1 - y_1.mean()) / y_1.std()

with pm.Model() as model_l: 
    
    # priors
    α = pm.Normal('α', mu = 0, sd = 5)
    β = pm.Normal('β', mu = 0, sd = 1) 
    ϵ = pm.HalfNormal('ϵ', 2)
    
    # linear model
    μ = pm.Deterministic('μ', α + β * x_1s[0]) 
    
    # likelihood
    y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)
    
    # sample 
    trace_l = pm.sample(2000, cores = 1)


# preprocessing
order = 2
x_1p = np.vstack([x_1**i for i in range(1, order + 1)])
x_1s = (x_1p - x_1p.mean(axis = 1, keepdims = True)) / x_1p.std(axis = 1, keepdims = True)
y_1s = (y_1 - y_1.mean()) / y_1.std()

with pm.Model() as model_p: 
    
    # priors
    α = pm.Normal('α', mu = 0, sd = 5)
    β = pm.Normal('β', mu = 0, sd = 1, shape = order) #2 predictors?
    ϵ = pm.HalfNormal('ϵ', 2)
    
    # linear model
    μ = α + pm.math.dot(β, x_1s) 
    
    # likelihood
    y = pm.Normal('y', mu = μ, sd = ϵ, observed = y_1s)
    
    # sample 
    trace_p = pm.sample(2000, cores = 1)
    
    # plot trace
    az.plot_trace(trace_p)

# %%
# posterior predictions
y_l = pm.sample_posterior_predictive(trace_l, 2000, 
                                    model = model_l)['y']
y_p = pm.sample_posterior_predictive(trace_p, 2000,
                                    model = model_p)['y']

# %%
# IQR visualization
plt.figure(figsize = (8, 3))
data = [y_1s, y_l, y_p]
labels = ['data', 'linear model', 'order 2']
for i, d in enumerate(data): 
    mean = d.mean() #what to do instead here?
    err = np.percentile(d, [25, 75])
    plt.errorbar(mean, -i, xerr = [[-err[0]], [err[1]]], fmt = 'o')
    plt.text(mean, -i + 0.2, labels[i], ha = 'center', fontsize = 14)
plt.ylim([-i-0.5, 0.5])
plt.yticks([])

# %%
# dispersion
fig, ax = plt.subplots(1, 2, figsize = (10, 3), constrained_layout = True)

def iqr(x, a = 0):
    return np.subtract(*np.percentile(x, [75, 25], axis = a))

for idx, func in enumerate([np.mean, iqr]):
    T_obs = func(y_1s)
    ax[idx].axvline(T_obs, 0, 1, color = 'k', ls = '--')
    
    for d_sim, c in zip([y_l, y_p], ['C1', 'C2']):
        T_sim = func(d_sim, 1)
        p_value = np.mean(T_sim >= T_obs)
        az.plot_kde(T_sim, plot_kwargs = {'color': c},
                   label = f'p-value {p_value:.2f}',
                   ax = ax[idx])
        ax[idx].set_title(func.__name__)
        ax[idx].set_yticks([])
        ax[idx].legend()

# %% [markdown]
# # E5
# Read and run the posterior predictive example from PyMC3's documentation at
# https:/​/​pymc-​devs.​github.​io/​pymc3/​notebooks/​posterior_​predictive.​html

# %%
# %matplotlib inline
import numpy as np
import pymc3 as pm
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
data = np.random.randn(100)

with pm.Model() as model:
    mu = pm.Normal('mu', mu=0, sd=1, testval=0)
    sd = pm.HalfNormal('sd', sd=1)
    n = pm.Normal('n', mu=mu, sd=sd, observed=data)

    trace = pm.sample(5000, cores = 1)

# %%
pm.traceplot(trace);

# %%
ppc = pm.sample_posterior_predictive(trace, samples=500, model=model, size=100)

# %%
np.asarray(ppc['n']).shape

# %%
ax = plt.subplot()
sns.distplot([n.mean() for n in ppc['n']], kde=False, ax=ax)
ax.axvline(data.mean())
ax.set(title='Posterior predictive of the mean', xlabel='mean(x)', ylabel='Frequency');

# %%
# Use a theano shared variable to be able to exchange the data the model runs on
from theano import shared

# %%
def invlogit(x):
    return np.exp(x) / (1 + np.exp(x))

n = 4000
n_oos = 50
coeff = 1.

predictors = np.random.normal(size=n)
# Turn predictor into a shared var so that we can change it later
predictors_shared = shared(predictors)

outcomes = np.random.binomial(1, invlogit(coeff * predictors))

# %%
outcomes

# %%
predictors_oos = np.random.normal(size=50)
outcomes_oos = np.random.binomial(1, invlogit(coeff * predictors_oos))

# %%
def tinvlogit(x):
    import theano.tensor as t
    return t.exp(x) / (1 + t.exp(x))

with pm.Model() as model:
    coeff = pm.Normal('coeff', mu=0, sd=1)
    p = tinvlogit(coeff * predictors_shared)

    o = pm.Bernoulli('o', p, observed=outcomes)

    trace = pm.sample(5000, n_init=5000, cores = 1)

# %%
# Changing values here will also change values in the model
predictors_shared.set_value(predictors_oos)

# %%
# Simply running PPC will use the updated values and do prediction
ppc = pm.sample_posterior_predictive(trace, model=model, samples=500)

# %%
plt.errorbar(x=predictors_oos, y=np.asarray(ppc['o']).mean(axis=0), yerr=np.asarray(ppc['o']).std(axis=0), linestyle='', marker='o')
plt.plot(predictors_oos, outcomes_oos, 'o')
plt.ylim(-.05, 1.05)
plt.xlabel('predictor')
plt.ylabel('outcome')

# %% [markdown]
# # E6
# Go back to the code that generated Figure 5.5 and Figure 5.6, and modify it to get
# new sets of six data points. Visually evaluate how the different polynomials fit
# these new datasets. Relate the results to the discussions in this book

# %%
x = np.array([4., 5., 6., 9., 12, 14.])
y = np.array([2, 6., 5., 9., 10, 10.])
plt.figure(figsize=(10, 5))
order = [0, 1, 2, 5]
plt.plot(x, y, 'o')
for i in order:
    x_n = np.linspace(x.min(), x.max(), 100)
    coeffs = np.polyfit(x, y, deg=i)
    ffit = np.polyval(coeffs, x_n)
    p = np.poly1d(coeffs)
    yhat = p(x)
    ybar = np.mean(y)
    ssreg = np.sum((yhat-ybar)**2)
    sstot = np.sum((y - ybar)**2)
    r2 = ssreg / sstot
    plt.plot(x_n, ffit, label=f'order {i}, $R^2$= {r2:.2f}')

plt.legend(loc=2)
plt.xlabel('x')
plt.ylabel('y', rotation=0)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Not sure whether there is so much to say.
# We know that the order 5 polynomial will always fit six points perfectly,
# because it has six degrees of freedom (the intercept as well).
# It has very high variance and learns too much from the data.
# The order 1 might have slightly too much bias (learns to little),
# but it is much more useful than the order 5 polynomial.
# From an information theory perspective the order 5 polynomial
# does not do any compression of information and as such just codes
# the information in a new (but uncompressed) format. It has not
# learned anything from the data.

# %% [markdown]
# # 7. E7
# Read and run the model averaging example from PyMC3's documentation at
# https:/​/​docs.​pymc.​io/​notebooks/​model_​averaging.​html

# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc3 as pm

# %%
RANDOM_SEED = 8927
np.random.seed(RANDOM_SEED)
az.style.use("arviz-darkgrid")

# %%
d = pd.read_csv(
    "https://raw.githubusercontent.com/pymc-devs/resources/master/Rethinking_2/Data/milk.csv",
    sep=";",)

d = d[["kcal.per.g", "neocortex.perc", "mass"]].rename({"neocortex.perc": "neocortex"}, axis=1)
d["log_mass"] = np.log(d["mass"])
d = d[~d.isna().any(axis=1)].drop("mass", axis=1)
d.iloc[:, 1:] = d.iloc[:, 1:] - d.iloc[:, 1:].mean()
d.head()
# Out:
#    kcal.per.g  neocortex  log_mass
# 0        0.49 -12.415882 -0.831486
# 5        0.47  -3.035882  0.158913
# 6        0.56  -3.035882  0.181513
# 7        0.89   0.064118 -0.579032
# 9        0.92   1.274118 -1.884978

# %%
with pm.Model() as neo: 
    
    # priors
    α = pm.Normal('α', mu = 0, sd = 10)
    β = pm.Normal('β', mu = 0, sd = 10)
    sigma = pm.HalfNormal('sigma', 10)
    
    # likelihood 
    μ = α + β * d["neocortex"]
    
    # y
    kcal = pm.Normal('kcal', mu = μ, sigma = sigma, observed = d["kcal.per.g"])
    
    # trace
    neo_trace = pm.sample(2000, return_inferencedata = True, cores = 1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, β, α]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:02<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:02<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 6 seconds.

# %%
with pm.Model() as mass: 
    
    # priors
    α = pm.Normal('α', mu = 0, sd = 10)
    β = pm.Normal('β', mu = 0, sd = 1)
    sigma = pm.HalfNormal('sigma', 10)
    
    # likelihood 
    μ = α + β * d["log_mass"]
    
    # y
    kcal = pm.Normal('kcal', mu = μ, sigma = sigma, observed = d["kcal.per.g"])
    
    # trace
    mass_trace = pm.sample(2000, return_inferencedata = True, cores = 1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, β, α]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:02<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:02<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 5 seconds.

# %%
with pm.Model() as two_pred:
    α = pm.Normal("α", mu=0, sigma=10)
    β = pm.Normal("beta", mu=0, sigma=1, shape=2)
    sigma = pm.HalfNormal("sigma", 10)

    mu = α + pm.math.dot(β, d[["neocortex", "log_mass"]].T) #.T = transposed?

    kcal = pm.Normal("kcal", mu=mu, sigma=sigma, observed=d["kcal.per.g"])

    double_trace = pm.sample(2000, cores = 1, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, beta, α]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:04<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:04<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 2_000 draw iterations (2_000 + 4_000 draws total) took 8 seconds.

# %%
traces = [neo_trace, mass_trace, double_trace]
az.plot_forest(traces, figsize=(10, 5));

# %%
az.plot_density(traces, var_names=["α", "sigma"]);

# %%
model_dict = dict(zip(["neo", "mass", "two_pred"], traces))
comp = az.compare(model_dict, method = "stacking")
comp
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:146: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   warnings.warn(
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:692: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.7 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
#           rank       loo     p_loo     d_loo    weight        se       dse  \
# two_pred     0  8.087158  3.504300  0.000000  0.985289  2.682581  0.000000
# mass         1  4.333345  2.141987  3.753813  0.000000  2.091473  1.811869
# neo          2  3.636399  1.928848  4.450759  0.014711  1.581775  2.617459
#
#           warning loo_scale
# two_pred     True       log
# mass        False       log
# neo         False       log

# %%
# doesn't really make sense that mass has better rank than neo but worse weight??
# also the warning??

# %%
# will this still work with ascending = True now that the names are different??
ppc_w = pm.sample_posterior_predictive_w(
    traces,
    1000,
    [neo, mass, two_pred],
    weights=comp.weight.sort_index(ascending=True),
    progressbar=True,
)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:03<00:00]
#     </div>

# %%
ppc_2 = pm.sample_posterior_predictive(double_trace, 1000, two_pred, progressbar=False)
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\sampling.py:1690: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   warnings.warn(

# %%
# comparing
# I get somewhat less difference than they do.
mean_w = ppc_w["kcal"].mean()
hpd_w = az.hdi(ppc_w["kcal"]).mean(0)

mean = ppc_2["kcal"].mean()
hpd = az.hdi(ppc_2["kcal"]).mean(0)

plt.plot(mean_w, 1, "C0o", label="weighted models")
plt.hlines(1, *hpd_w, "C0")
plt.plot(mean, 0, "C1o", label="model 2")
plt.hlines(0, *hpd, "C1")

plt.yticks([])
plt.ylim(-1, 2)
plt.xlabel("kcal per g")
plt.legend();

# %% [markdown]
# # E8
# Compute the Bayes factor for the coin problem using a uniform prior beta (1, 1)
# and priors such as beta (0.5, 0.5). Set 15 heads and 30 coins. Compare this result
# with the inference we got in the first chapter of this book.

# %%
# balanced coins
coins = 30
heads = 15
y_d = np.repeat([0, 1], [coins-heads, heads])

# %%
# could this be done with tensor instead of math?
with pm.Model() as m1:
    θ = pm.Beta('θ', 1, 1) #uniform I think. 
    y = pm.Bernoulli('y', θ, observed = y_d)
    t1 = pm.sample_smc(2500, cores = 1)
# Out:
# Initializing SMC sampler...
# Sampling 2 chains in 1 job
# Stage:   0 Beta: 0.340
# Stage:   1 Beta: 1.000
# Stage:   0 Beta: 0.328
# Stage:   1 Beta: 1.000

# %%
with pm.Model() as m2:
    θ = pm.Beta('θ', 0.5, 0.5) #convex (so bad..)
    y = pm.Bernoulli('y', θ, observed = y_d)
    t2 = pm.sample_smc(2500, cores = 1)
# Out:
# Initializing SMC sampler...
# Sampling 2 chains in 1 job
# Stage:   0 Beta: 0.140
# Stage:   1 Beta: 1.000
# Stage:   0 Beta: 0.146
# Stage:   1 Beta: 1.000

# %%
# marginal likelihood appears to have changed also. 
# not sure why there are two numbers: but both are close to the 11 mentioned in the book. 
BF_smc = np.exp(t1.report.log_marginal_likelihood - t2.report.log_marginal_likelihood)
BF_smc
# Out:
# array([1.54525119, 1.49547083])

# %%
# so... does this mean that model 1 is twice as good as model 2?

# %%
w1 = az.waic(t1)
w2 = az.waic(t2)

# %%
waics = []
waics.append(w1)
waics.append(w2)

# %%
# Model 1 has all the weight. 
model_dict = dict(zip(["m1", "m2"], [t1, t2]))
comp = az.compare(model_dict, method = "stacking")
comp
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:146: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   warnings.warn(
#     rank       loo     p_loo     d_loo  weight        se       dse  warning  \
# m1     0 -7.882590  0.951055  0.000000     1.0  0.017586  0.000000    False
# m2     1 -7.981521  1.049947  0.098931     0.0  0.019221  0.001635    False
#
#    loo_scale
# m1       log
# m2       log

# %%
fig, ax = plt.subplots()

labels = ['beta 1-1', 'beta 0.5-0.5']
indices = [0, 1]

for i, (ind, d) in enumerate(zip(indices, waics)): 
    mean = d.waic
    ax.errorbar(mean, -i, xerr = d.waic_se, fmt = 'o')
    ax.text(mean, -i + 0.2, labels[i], ha = 'center')

# %%
# not sure what we got in chapter 1. 
# I would assume that we found that the 
# likelihood (data) was enough to overpower the prior
# as such the posterior inference should be roughly
# the same. However, bayes factor (as we know) 
# depends on the prior (because the marginal likelihood does).

# %% [markdown]
# # E9:
# Repeat the last example where we compare Bayes factors and Information
# Criteria, but now reduce the sample size.

# %%
# balanced coins (smaller sampel size)
coins = 10
heads = 5
y_d = np.repeat([0, 1], [coins-heads, heads])

# %%
# could this be done with tensor instead of math?
with pm.Model() as m1:
    θ = pm.Beta('θ', 1, 1) #uniform I think. 
    y = pm.Bernoulli('y', θ, observed = y_d)
    t1 = pm.sample_smc(2500, cores = 1)
    
with pm.Model() as m2:
    θ = pm.Beta('θ', 0.5, 0.5) #convex (so bad..)
    y = pm.Bernoulli('y', θ, observed = y_d)
    t2 = pm.sample_smc(2500, cores = 1)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock C:\Users\95\AppData\Local\Theano\compiledir_Windows-10-10.0.19041-SP0-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-3.8.5-64\lock_dir\lock
# Initializing SMC sampler...
# Sampling 2 chains in 1 job
# Stage:   0 Beta: 1.000
# Stage:   0 Beta: 1.000
# Initializing SMC sampler...
# Sampling 2 chains in 1 job
# Stage:   0 Beta: 0.432
# Stage:   1 Beta: 1.000
# Stage:   0 Beta: 0.415
# Stage:   1 Beta: 1.000

# %%
# now I get two different things - need to find out why this is the case. 
BF_smc = np.exp(t1.report.log_marginal_likelihood - t2.report.log_marginal_likelihood)
BF_smc # just two similar estimates I guess.
# Out:
# array([1.54525119, 1.49547083])

# %%
# model 1 still has all the weight
model_dict = dict(zip(["m1", "m2"], [t1, t2]))
comp = az.compare(model_dict, method = "stacking")
comp
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:146: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   warnings.warn(
#     rank       loo     p_loo     d_loo  weight        se       dse  warning  \
# m1     0 -7.882590  0.951055  0.000000     1.0  0.017586  0.000000    False
# m2     1 -7.981521  1.049947  0.098931     0.0  0.019221  0.001635    False
#
#    loo_scale
# m1       log
# m2       log

# %%
# relative diff seems the same, but they are both ?more? uncertain.
waics = []
waics.append(az.waic(t1))
waics.append(az.waic(t2))

fig, ax = plt.subplots()

labels = ['beta 1-1', 'beta 0.5-0.5']
indices = [0, 1]

for i, (ind, d) in enumerate(zip(indices, waics)): 
    mean = d.waic
    ax.errorbar(mean, -i, xerr = d.waic_se, fmt = 'o')
    ax.text(mean, -i + 0.2, labels[i], ha = 'center')

# %% [markdown]
# # E10
# For the entropy example, change the q distribution. Try this with distributions
# like stats.binom(10, 0.5) and stats.binom(10, 0.25).

# %%
from scipy import stats

# %%
# from the book
x = range(0, 10)
q = stats.binom(10, .75)
r = stats.randint(0, 10)

true_distribution = [list(q.rvs(200)).count(i) / 200 for i in x]

q_pmf = q.pmf(x)
r_pmf = r.pmf(x)

_, ax = plt.subplots(1, 3, figsize = (12, 4),
                    sharey = True, constrained_layout = True)

for idx, (dist, label) in enumerate(zip([true_distribution, q_pmf, r_pmf],
                                       ['true_distribution', 'q', 'r'])):
    ax[idx].vlines(x, 0, dist, label = f'entropy = {stats.entropy(dist):.2f}')
    ax[idx].set_title(label)
    ax[idx].set_yticks(x)
    ax[idx].legend(loc = 2, handlelength = 0)

# %%
stats.entropy(true_distribution, q_pmf), stats.entropy(true_distribution, r_pmf)
# Out:
# (0.014916060309842875, 0.7202127117206231)

# %%
# making it into a function
def plot_dist(q_prob):
    
    x = range(0, 10)
    q = stats.binom(10, q_prob)
    r = stats.randint(0, 10)

    true_distribution = [list(q.rvs(200)).count(i) / 200 for i in x]

    q_pmf = q.pmf(x)
    r_pmf = r.pmf(x)

    _, ax = plt.subplots(1, 3, figsize = (12, 4),
                        sharey = True, constrained_layout = True)

    for idx, (dist, label) in enumerate(zip([true_distribution, q_pmf, r_pmf],
                                           ['true_distribution', 'q', 'r'])):
        ax[idx].vlines(x, 0, dist, label = f'entropy = {stats.entropy(dist):.2f}')
        ax[idx].set_title(label)
        ax[idx].set_yticks(x)
        ax[idx].legend(loc = 2, handlelength = 0)

# %%
plot_dist(0.5)
