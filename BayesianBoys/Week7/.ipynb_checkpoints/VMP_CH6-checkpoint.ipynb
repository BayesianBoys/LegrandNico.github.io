# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pymc3 as pm
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import arviz as az
import theano.tensor as tt

# %%
cs = pd.read_csv("../data/chemical_shifts_theo_exp.csv")
cs_exp = cs['exp']
az.plot_kde(cs_exp)
plt.hist(cs_exp, density = True, bins = 30, alpha = 0.3)
plt.yticks([]);

# %%
cs.head(2)
# Out:
#      ID   aa   theo    exp
# 0  1BM8  ILE  61.18  58.27
# 1  1BM8  TYR  56.95  56.18

# %% [markdown]
# # Categorical distribution

# %%
# very slow, very bad. 
clusters = 2
with pm.Model() as model_kg:
    p = pm.Dirichlet('p', a = np.ones(clusters)) #uniform
    z = pm.Categorical('z', p = p, shape = len(cs_exp))
    means = pm.Normal('means', mu = cs_exp.mean(), 
                     sd = 10, shape = clusters)
    sd = pm.HalfNormal('sd', sd = 10)
    
    y = pm.Normal('y', mu = means[z], sd = sd, observed = cs_exp)
    trace_kg = pm.sample()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-553f6c07e981> in <module>
#       2 clusters = 2
#       3 with pm.Model() as model_kg:
# ----> 4     p = pm.Dirichlet('p', a = np.ones(clusters)) #uniform
#       5     z = pm.Categorical('z', p = p, shape = len(cs_exp))
#       6     means = pm.Normal('means', mu = cs_exp.mean(),
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\distributions\distribution.py in __new__(cls, name, *args, **kwargs)
#     119             dist = cls.dist(*args, **kwargs, shape=shape)
#     120         else:
# --> 121             dist = cls.dist(*args, **kwargs)
#     122         return model.Var(name, dist, data, total_size, dims=dims)
#     123
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\distributions\distribution.py in dist(cls, *args, **kwargs)
#     128     def dist(cls, *args, **kwargs):
#     129         dist = object.__new__(cls)
# --> 130         dist.__init__(*args, **kwargs)
#     131         return dist
#     132
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\distributions\multivariate.py in __init__(self, a, transform, *args, **kwargs)
#     474
#     475         self.a = a = tt.as_tensor_variable(a)
# --> 476         self.mean = a / tt.sum(a)
#     477
#     478         self.mode = tt.switch(tt.all(a > 1), (a - 1) / tt.sum(a - 1), np.nan)
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\tensor\basic.py in sum(input, axis, dtype, keepdims, acc_dtype)
#    3219     """
#    3220
# -> 3221     out = elemwise.Sum(axis=axis, dtype=dtype, acc_dtype=acc_dtype)(input)
#    3222
#    3223     if keepdims:
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\graph\op.py in __call__(self, *inputs, **kwargs)
#     251
#     252         if config.compute_test_value != "off":
# --> 253             compute_test_value(node)
#     254
#     255         if self.default_output is not None:
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\graph\op.py in compute_test_value(node)
#     124
#     125     # Create a thunk that performs the computation
# --> 126     thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#     127     thunk.inputs = [storage_map[v] for v in node.inputs]
#     128     thunk.outputs = [storage_map[v] for v in node.outputs]
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\graph\op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     632             )
#     633             try:
# --> 634                 return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#     635             except (NotImplementedError, MethodNotDefined):
#     636                 # We requested the c code, so don't catch the error.
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\graph\op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     598                 print(f"Disabling C code for {self} due to unsupported float16")
#     599                 raise NotImplementedError("float16")
# --> 600         outputs = cl.make_thunk(
#     601             input_storage=node_input_storage, output_storage=node_output_storage
#     602         )
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\basic.py in make_thunk(self, input_storage, output_storage, storage_map)
#    1201         """
#    1202         init_tasks, tasks = self.get_init_tasks()
# -> 1203         cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1204             input_storage, output_storage, storage_map
#    1205         )
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\basic.py in __compile__(self, input_storage, output_storage, storage_map)
#    1136         input_storage = tuple(input_storage)
#    1137         output_storage = tuple(output_storage)
# -> 1138         thunk, module = self.cthunk_factory(
#    1139             error_storage,
#    1140             input_storage,
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\basic.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map)
#    1632             for node in self.node_order:
#    1633                 node.op.prepare_node(node, storage_map, None, "c")
# -> 1634             module = get_module_cache().module_from_key(key=key, lnk=self)
#    1635
#    1636         vars = self.inputs + self.outputs + self.orphans
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\basic.py in get_module_cache(init_args)
#      46
#      47     """
# ---> 48     return _get_module_cache(config.compiledir, init_args=init_args)
#      49
#      50
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\cmodule.py in get_module_cache(dirname, init_args)
#    1593         init_args = {}
#    1594     if _module_cache is None:
# -> 1595         _module_cache = ModuleCache(dirname, **init_args)
#    1596         atexit.register(_module_cache._on_atexit)
#    1597     elif init_args:
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\cmodule.py in __init__(self, dirname, check_for_broken_eq, do_refresh)
#     681
#     682         if do_refresh:
# --> 683             self.refresh()
#     684
#     685     age_thresh_use = config.cmodule__age_thresh_use  # default 24 days
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\theano\link\c\cmodule.py in refresh(self, age_thresh_use, delete_if_problem, cleanup)
#     806
#     807                     try:
# --> 808                         with open(key_pkl, "rb") as f:
#     809                             key_data = pickle.load(f)
#     810                     except EOFError:
#
# KeyboardInterrupt:

# %%
# reparameterized
clusters = 2 
with pm.Model() as model_mg:
    p = pm.Dirichlet('p', a = np.ones(clusters))
    means = pm.Normal('means', mu = cs_exp.mean(), 
                     sd = 10, shape = clusters)
    sd = pm.HalfNormal('sd', sd = 10)
    y = pm.NormalMixture('y', w = p, mu = means, sd = sd, observed = cs_exp)
    trace_mg = pm.sample(cores = 1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, means, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:07<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:08<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 15 seconds.

# %%
varnames = ['means', 'p']
az.plot_trace(trace_mg, varnames)
# Out:
# array([[<AxesSubplot:title={'center':'means'}>,
#         <AxesSubplot:title={'center':'means'}>],
#        [<AxesSubplot:title={'center':'p'}>,
#         <AxesSubplot:title={'center':'p'}>]], dtype=object)

# %%
# seems like they "fixed" this..?
az.summary(trace_mg, varnames)
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# means[0]  46.843  0.437  46.056   47.682      0.010    0.007    1910.0
# means[1]  57.465  0.103  57.280   57.661      0.002    0.002    2337.0
# p[0]       0.090  0.009   0.074    0.108      0.000    0.000    1602.0
# p[1]       0.910  0.009   0.892    0.926      0.000    0.000    1602.0
#
#           ess_sd  ess_bulk  ess_tail  r_hat
# means[0]  1908.0    1910.0    1532.0    1.0
# means[1]  2337.0    2334.0    1543.0    1.0
# p[0]      1598.0    1612.0    1627.0    1.0
# p[1]      1602.0    1612.0    1627.0    1.0

# %%
clusters = 2
with pm.Model() as model_mgp:
    p = pm.Dirichlet('p', a=np.ones(clusters))
    means = pm.Normal('means', mu=np.array([.9, 1]) * cs_exp.mean(),
                      sd=10, shape=clusters)
    sd = pm.HalfNormal('sd', sd=10)
    order_means = pm.Potential('order_means',tt.switch(means[1]-means[0] < 0,
                                                      -np.inf, 0))
    y = pm.NormalMixture('y', w = p, mu = means, sd = sd, observed = cs_exp)
    trace_mpg = pm.sample(1000, cores = 1)
    
varnames = ['means', 'p']
az.plot_trace(trace_mpg, varnames)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, means, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:07<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:07<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 15 seconds.
# array([[<AxesSubplot:title={'center':'means'}>,
#         <AxesSubplot:title={'center':'means'}>],
#        [<AxesSubplot:title={'center':'p'}>,
#         <AxesSubplot:title={'center':'p'}>]], dtype=object)

# %%
# again, this is great - but it does seem like they fixed it..
az.summary(trace_mpg)
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  \
# means[0]  46.843  0.457  46.018   47.678      0.011    0.008    1804.0
# means[1]  57.464  0.102  57.274   57.658      0.003    0.002    1573.0
# p[0]       0.091  0.009   0.074    0.109      0.000    0.000    1687.0
# p[1]       0.909  0.009   0.891    0.926      0.000    0.000    1687.0
# sd         3.651  0.077   3.511    3.792      0.002    0.001    2593.0
#
#           ess_sd  ess_bulk  ess_tail  r_hat
# means[0]  1802.0    1816.0    1509.0    1.0
# means[1]  1573.0    1579.0    1408.0    1.0
# p[0]      1650.0    1703.0    1426.0    1.0
# p[1]      1687.0    1703.0    1426.0    1.0
# sd        2593.0    2585.0    1526.0    1.0

# %%
# p_min = pm.Potential('p_min', tt.switch(tt.min(p) < min_p, -np.inf, 0))
# above ensurs that each "class" gets at least one observation attached..
# set min_p to some low value (e.g. 0.1, 0.01).

# %%
# alpha for Dirichlet in [4, 10] is good baseline. (higher values, more informative prior).

# %% [markdown]
# # Choosing K

# %%
clusters = [3, 4, 5, 6]
models = []
traces = []

for cluster in clusters:
    with pm.Model() as model:
        p = pm.Dirichlet('p', a = np.ones(cluster))
        means = pm.Normal('means', 
                         mu = np.linspace(cs_exp.min(), cs_exp.max(),
                                         cluster),
                         sd = 10, shape = cluster,
                         transform = pm.distributions.transforms.ordered)
        sd = pm.HalfNormal('sd', sd = 10)
        y = pm.NormalMixture('y', w = p, mu = means, sd = sd, observed = cs_exp)
        
        trace = pm.sample(1000, tune = 2000, cores = 1)
        traces.append(trace)
        models.append(model)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, means, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:37<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 02:10<00:00 Sampling chain 1, 29 divergences]
#     </div>
# Sampling 2 chains for 2_000 tune and 1_000 draw iterations (4_000 + 2_000 draws total) took 168 seconds.
# There were 29 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, means, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:38<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:50<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 2_000 tune and 1_000 draw iterations (4_000 + 2_000 draws total) took 89 seconds.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, means, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 01:36<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 01:32<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 2_000 tune and 1_000 draw iterations (4_000 + 2_000 draws total) took 189 seconds.
# The acceptance probability does not match the target. It is 0.8874507472320052, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, means, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 02:31<00:00 Sampling chain 0, 3 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 03:07<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 2_000 tune and 1_000 draw iterations (4_000 + 2_000 draws total) took 339 seconds.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9289101701329208, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
from scipy import stats

# %%
# crazy plot (very cool). 
_, ax = plt.subplots(2, 2, figsize = (11, 8), constrained_layout = True)

ax = np.ravel(ax)
x = np.linspace(cs_exp.min(), cs_exp.max(), 200)

for idx, trace_x in enumerate(traces):
    x_ = np.array([x] * clusters[idx]).T 
    
    for i in range(50): 
        i_ = np.random.randint(0, len(trace_x))
        means_y = trace_x['means'][i_]
        p_y = trace_x['p'][i_]
        sd = trace_x['sd'][i_]
        dist = stats.norm(means_y, sd)
        ax[idx].plot(x, np.sum(dist.pdf(x_) * p_y, 1), 'C0', alpha = 0.1)
        
    means_y = trace_x['means'].mean(0)
    p_y = trace_x['p'].mean(0)
    sd = trace_x['sd'].mean()
    dist = stats.norm(means_y, sd)
    ax[idx].plot(x, np.sum(dist.pdf(x_) * p_y, 1), 'C0', lw = 2)
    ax[idx].plot(x, dist.pdf(x_) * p_y, 'k--', alpha = 0.7)
    az.plot_kde(cs_exp, plot_kwargs = {'linewidth':2,
                                      'color':'k'},
                ax = ax[idx])
    
    ax[idx].set_title('K = {}'.format(clusters[idx]))
    ax[idx].set_yticks([])
    ax[idx].set_xlabel('x')

# %%
# the values I get are pretty different.
ppc_mm = [pm.sample_posterior_predictive(traces[i], 1000, models[i]) for i in range(4)]
fig, ax = plt.subplots(2, 2, figsize=(10, 6), sharex=True, constrained_layout=True)
ax = np.ravel(ax)

def iqr(x, a=0):
    return np.subtract(*np.percentile(x, [75, 25], axis=a))

T_obs = iqr(cs_exp)

for idx, d_sim in enumerate(ppc_mm):
    T_sim = iqr(d_sim['y'][:100].T, 1)
    p_value = np.mean(T_sim >= T_obs)
    az.plot_kde(T_sim, ax=ax[idx])
    ax[idx].axvline(T_obs, 0, 1, color='k', ls='--')
    ax[idx].set_title(f'K = {clusters[idx]} \n p-value {p_value:.2f}')
    ax[idx].set_yticks([])
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pymc3\sampling.py:1690: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   warnings.warn(
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 01:31<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 01:28<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 01:27<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 01:27<00:00]
#     </div>

# %%
# which model is best acc. to IC?
# again, crazy values & it does not really correspond to the above.
# also weight should not ~1 for the best, but rather something like ~.95 (at most). 
# there is a -2 multiplier basically from the variance.. 
# just don't understand why the weight is so affected...
comp = az.compare(dict(zip(clusters, traces)), method = 'stacking', 
                  ic = "waic") #stacking rather. 
comp
# Out:
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\stats\stats.py:146: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   warnings.warn(
#    rank         waic     p_waic     d_waic        weight         se  \
# 6     0 -5124.868782  12.313136   0.000000  1.000000e+00  30.794319
# 5     1 -5129.427883  10.028273   4.559102  1.220357e-10  30.784592
# 4     2 -5139.562057   7.586708  14.693276  1.009113e-10  31.238796
# 3     3 -5203.933626  17.611434  79.064844  0.000000e+00  32.537720
#
#          dse  warning waic_scale
# 6   0.000000    False        log
# 5   2.298516    False        log
# 4   4.944932    False        log
# 3  10.493990    False        log

# %%
# some error here..?
az.plot_compare(comp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-0c8401187967> in <module>
#       1 # some error here..?
# ----> 2 az.plot_compare(comp)
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\plots\compareplot.py in plot_compare(comp_df, insample_dev, plot_standard_error, plot_ic_diff, order_by_rank, figsize, textsize, plot_kwargs, ax, backend, backend_kwargs, show)
#     135     # TODO: Add backend kwargs
#     136     plot = get_plotting_function("plot_compare", "compareplot", backend)
# --> 137     ax = plot(**compareplot_kwargs)
#     138
#     139     return ax
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\arviz\plots\backends\matplotlib\compareplot.py in plot_compare(ax, comp_df, figsize, plot_ic_diff, plot_standard_error, insample_dev, yticks_pos, yticks_labels, plot_kwargs, information_criterion, textsize, step, backend_kwargs, show)
#      83
#      84     if insample_dev:
# ---> 85         scale = comp_df[f"{information_criterion}_scale"][0]
#      86         p_ic = comp_df[f"p_{information_criterion}"]
#      87         if scale == "log":
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     822
#     823         elif key_is_scalar:
# --> 824             return self._get_value(key)
#     825
#     826         if is_hashable(key):
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     930
#     931         # Similar to Index.get_value, but we do not fall back to positional
# --> 932         loc = self.index.get_loc(label)
#     933         return self.index._get_values_for_loc(self, loc, label)
#     934
#
# c:\users\95\anaconda3\envs\cogmod\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# # Mixture models & clustering

# %% [markdown]
# # Non-finite mixture models

# %% [markdown]
# # Dirichlet process

# %%
def stick_breaking_truncated(α, H, K):
    """
    Truncated stick-breaking process view of a DP

    Parameters
    ----------
    α : float concentration parameter
    H : scipy distribution Base distribution
    K : int. number of components

    Returns
    -------
    locs : array locations
    w : array probabilities
    """

    βs = stats.beta.rvs(1, α, size=K)
    w = np.empty(K)
    w = βs * np.concatenate(([1.], np.cumprod(1 - βs[:-1])))
    locs = H.rvs(size=K)
    return locs, w

# %%
# Parameters DP
K = 500
H = stats.norm
alphas = [1, 10, 100, 1000]
_, ax = plt.subplots(2, 2, sharex=True, figsize=(10, 5))
ax = np.ravel(ax)

for idx, α in enumerate(alphas):
    locs, w = stick_breaking_truncated(α, H, K)
    ax[idx].vlines(locs, 0, w, color='C0')
    ax[idx].set_title('α = {}'.format(α))
    
plt.tight_layout()

# %%
α = 10
H = stats.norm
K = 5
x = np.linspace(-4, 4, 250)
x_ = np.array([x] * K).T
locs, w = stick_breaking_truncated(α, H, K)
dist = stats.laplace(locs, 0.5)
plt.plot(x, np.sum(dist.pdf(x_) * w, 1), 'C0', lw=2)
plt.plot(x, dist.pdf(x_) * w, 'k--', alpha=0.7)
plt.yticks([])
# Out:
# ([], [])

# %%
N = cs_exp.shape[0]
K = 20

def stick_breaking(α):
    β = pm.Beta('β', 1., α, shape=K)
    w = β * pm.math.concatenate([[1.], tt.extra_ops.cumprod(1. - β)[:-1]])
    return w

# %%
# gamma as concentration parameter.
# small thing to tweak here.
with pm.Model() as model:
    α = pm.Gamma('α', 1., 1.)
    w = pm.Deterministic('w', stick_breaking(α))
    means = pm.Normal('means', mu=cs_exp.mean(), sd=10, shape=K)
    sd = pm.HalfNormal('sd', sd=10, shape=K)
    obs = pm.NormalMixture('obs', w, means, sd=sd, observed=cs_exp.values)
    trace = pm.sample(1000, tune=2000, target_accept = 0.9) #changed this..?
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...

# %%
# should be many 
plt.figure(figsize=(8, 6))
plot_w = np.arange(K)
plt.plot(plot_w, trace['w'].mean(0), 'o-')
plt.xticks(plot_w, plot_w+1)
plt.xlabel('Component')
plt.ylabel('Average weight')
